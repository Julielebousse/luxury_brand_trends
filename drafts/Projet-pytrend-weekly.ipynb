# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta
from pytrends.request import TrendReq
import time
import pandas as pd
import matplotlib
pytrend = TrendReq()
plt.style.use('seaborn-darkgrid')
matplotlib.rcParams['font.family'] = ['Heiti TC']
def rmax(maxrow: int=50):
    pd.set_option('display.max_rows', maxrow)

def cmax(maxcol: int=50):
    pd.set_option('display.max_columns', maxcol)

# %%
brands =['Louis Vuitton','Gucci', 'Hermes', 'Dior', 'Bottega veneta']

# %%
brands_codes =[pytrend.suggestions(keyword=i)[0] for i in brands]

# %%
df_brands= pd.DataFrame(brands_codes)

# %%
exact_keywords=df_brands['mid'].to_list()
date_interval ='2020-01-01 2021-01-01'
#Countries=["US","IT","FR"] #Country code
category=185 # Select categories
search_type ='' #default is 'web searches',others include 'images','news','youtube','froogle' (google shopping)

# %%
individual_exact_keyword = list(zip(*[iter(exact_keywords)]*1))

# %%
individual_exact_keyword = [list(x) for x in individual_exact_keyword]

# %%
dicti = {}
i = 1
for keyword in individual_exact_keyword:
    pytrend.build_payload(kw_list=keyword, 
                          timeframe = date_interval, 
                          cat=category,
                          gprop=search_type) 
    dicti[i] = pytrend.interest_over_time()
    i+=1
df_brands_data = pd.concat(dicti, axis=1)

# %%
df_brands_data.columns = df_brands_data.columns.droplevel(0) #drop outside header

# %%
df_brands_data = df_brands_data.drop('isPartial', axis = 1) #drop "isPartial"
df_brands_data.reset_index(level=0,inplace=True) #reset_index
df_brands_data.columns=['date','Louis Vuitton','Gucci', 'Hermes', 'Dior', 'Bottega veneta'] #change column names

# %%
df_brands_data
# Out:
#          date  Louis Vuitton  Gucci  Hermes  Dior  Bottega veneta
# 0  2020-01-05             81     44      64    57              72
# 1  2020-01-12             77     41      68    57              52
# 2  2020-01-19             77     39      56    66              60
# 3  2020-01-26             67     31      73    53              42
# 4  2020-02-02             69     34      50    59              45
# 5  2020-02-09             74     36      64    60              59
# 6  2020-02-16             72     38      63    62              89
# 7  2020-02-23             69     36      47    60              97
# 8  2020-03-01             65     33      74    58              53
# 9  2020-03-08             57     30      40    51              53
# 10 2020-03-15             48     22      37    42              52
# 11 2020-03-22             48     27      48    40              38
# 12 2020-03-29             52     26      32    43              25
# 13 2020-04-05             52     26      37    44              45
# 14 2020-04-12             56     30      72    50              44
# 15 2020-04-19             57     29      42    48              22
# 16 2020-04-26             62     28      51    50              31
# 17 2020-05-03             66     32      74    54              41
# 18 2020-05-10             69     33      49    60              51
# 19 2020-05-17             68     33      43    55              58
# 20 2020-05-24             68     34      78    57              42
# 21 2020-05-31             67     33      52    68              48
# 22 2020-06-07             66     34      36    59              32
# 23 2020-06-14             67     34      86    62              58
# 24 2020-06-21             67     35      72    79              33
# 25 2020-06-28             69     36      68    79              53
# 26 2020-07-05             72     40      68    86              77
# 27 2020-07-12             75     38      70    87              72
# 28 2020-07-19             77     41      68    93              28
# 29 2020-07-26             75     36      66    79              59
# 30 2020-08-02             75     37      76    72              38
# 31 2020-08-09             73     37      79    69              51
# 32 2020-08-16             74     36      82    76              58
# 33 2020-08-23             72     41      87    71              34
# 34 2020-08-30             73    100      44    68              79
# 35 2020-09-06             73     43      63    74              76
# 36 2020-09-13             75     37      75    70              65
# 37 2020-09-20             75     37      73    67              62
# 38 2020-09-27             70     35      62    68              57
# 39 2020-10-04             75     39      79    69              68
# 40 2020-10-11             73     35      67    70              64
# 41 2020-10-18             67     36      65    69              60
# 42 2020-10-25             64     29      55    67              63
# 43 2020-11-01             61     30      54    69              56
# 44 2020-11-08             68     33      77    70              69
# 45 2020-11-15             72     35      78    77              59
# 46 2020-11-22             77     39      92    81              55
# 47 2020-11-29             81     34      89    80              55
# 48 2020-12-06             85     37      70    90              83
# 49 2020-12-13             83     40     100    86              84
# 50 2020-12-20            100     44      95   100              65
# 51 2020-12-27             89     41      61    94             100

# %%
df_brands_data.set_index("date")
# Out:
#             Louis Vuitton  Gucci  Hermes  Dior  Bottega veneta
# date
# 2020-01-05             81     44      64    57              72
# 2020-01-12             77     41      68    57              52
# 2020-01-19             77     39      56    66              60
# 2020-01-26             67     31      73    53              42
# 2020-02-02             69     34      50    59              45
# 2020-02-09             74     36      64    60              59
# 2020-02-16             72     38      63    62              89
# 2020-02-23             69     36      47    60              97
# 2020-03-01             65     33      74    58              53
# 2020-03-08             57     30      40    51              53
# 2020-03-15             48     22      37    42              52
# 2020-03-22             48     27      48    40              38
# 2020-03-29             52     26      32    43              25
# 2020-04-05             52     26      37    44              45
# 2020-04-12             56     30      72    50              44
# 2020-04-19             57     29      42    48              22
# 2020-04-26             62     28      51    50              31
# 2020-05-03             66     32      74    54              41
# 2020-05-10             69     33      49    60              51
# 2020-05-17             68     33      43    55              58
# 2020-05-24             68     34      78    57              42
# 2020-05-31             67     33      52    68              48
# 2020-06-07             66     34      36    59              32
# 2020-06-14             67     34      86    62              58
# 2020-06-21             67     35      72    79              33
# 2020-06-28             69     36      68    79              53
# 2020-07-05             72     40      68    86              77
# 2020-07-12             75     38      70    87              72
# 2020-07-19             77     41      68    93              28
# 2020-07-26             75     36      66    79              59
# 2020-08-02             75     37      76    72              38
# 2020-08-09             73     37      79    69              51
# 2020-08-16             74     36      82    76              58
# 2020-08-23             72     41      87    71              34
# 2020-08-30             73    100      44    68              79
# 2020-09-06             73     43      63    74              76
# 2020-09-13             75     37      75    70              65
# 2020-09-20             75     37      73    67              62
# 2020-09-27             70     35      62    68              57
# 2020-10-04             75     39      79    69              68
# 2020-10-11             73     35      67    70              64
# 2020-10-18             67     36      65    69              60
# 2020-10-25             64     29      55    67              63
# 2020-11-01             61     30      54    69              56
# 2020-11-08             68     33      77    70              69
# 2020-11-15             72     35      78    77              59
# 2020-11-22             77     39      92    81              55
# 2020-11-29             81     34      89    80              55
# 2020-12-06             85     37      70    90              83
# 2020-12-13             83     40     100    86              84
# 2020-12-20            100     44      95   100              65
# 2020-12-27             89     41      61    94             100

# %%
df_brands_data.plot(x = "date" , y = brands[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1e1db80e2f6d> in <module>
# ----> 1 df_brands_data.plot(x = "date" , y = brands[0])
#
# NameError: name 'df_brands_data' is not defined
