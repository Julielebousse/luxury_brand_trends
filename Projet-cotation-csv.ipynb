# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt

# %%
columns = ['date', 'value', 'volume']

# %%
data_kering = pd.read_csv('KERING_bourse.csv',sep=';', names = columns, skiprows=1)
data_hermes = pd.read_csv('HERMES_bourse.csv',sep=';', names = columns, skiprows=1)
data_lvmh = pd.read_csv('LVMH_bourse.csv',sep=';', names = columns, skiprows=1)
data_CAC40 = pd.read_csv('CAC40.csv',sep=';', names = columns, skiprows=1)

# %%
df_data_kering = pd.DataFrame(data_kering)
df_data_hermes = pd.DataFrame(data_hermes)
df_data_lvmh = pd.DataFrame(data_lvmh)
df_data_cac40 = pd.DataFrame(data_CAC40)

# %%
df_data_kering
# Out:
#                  date  value  volume
# 0    02/01/2020 01:00  598.0  178651
# 1    03/01/2020 01:00  600.9  159019
# 2    06/01/2020 01:00  590.8  176511
# 3    07/01/2020 01:00  596.3  201861
# 4    08/01/2020 01:00  597.3  201239
# ..                ...    ...     ...
# 252  24/12/2020 01:00  552.7   30846
# 253  28/12/2020 01:00  571.4  156244
# 254  29/12/2020 01:00  577.5  135269
# 255  30/12/2020 01:00  588.0  179344
# 256  31/12/2020 01:00  594.4   64795
#
# [257 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_data_kering['date'], df_data_kering['value'])
plt.plot(df_data_hermes['date'], df_data_hermes['value'])
plt.plot(df_data_lvmh['date'], df_data_lvmh['value'])
plt.plot(df_data_cac40['date'], df_data_cac40['value'])
plt.show()

# %%
# ne pas utiliser
import matplotlib.pyplot as plt
import csv
  
x = []
y = []
  
with open('HERMES_bourse.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ';')
      
    for row in plots:
        x.append(row[0])
        y.append(row[1])
  
plt.bar(x, y, label = "Date")
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Actions value')
plt.legend()
plt.show()

# %%
x = []
y = []
  
with open('hermes_bourse.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ';')
      
    for row in plots:
        x.append(row[0])
        y.append(row[2])
  
plt.plot(x, y, label = "Action volume")
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Actions volume')
plt.legend()
plt.show()

# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytrends 
# import the TrendReq method from the pytrends request module
from pytrends.request import TrendReq

# execute the TrendReq method by passing the host language (hl) and timezone (tz) parameters
pytrends = TrendReq(hl='fr', tz=360)

# %%
# build list of keywords
kw_list = ["Louis Vuitton", "Gucci", "Hermes"] 

# build the payload
pytrends.build_payload(kw_list, timeframe='2020-01-01 2021-01-01', geo='FR')

# %%
df = pytrends.interest_over_time()
print(df.head(20))
# Out:
#             Louis Vuitton  Gucci  Hermes  isPartial
# date
# 2020-01-05             80     69      58      False
# 2020-01-12             87     64      61      False
# 2020-01-19             85     62      51      False
# 2020-01-26             73     52      53      False
# 2020-02-02             82     58      92      False
# 2020-02-09             79     62      94      False
# 2020-02-16             85     63      58      False
# 2020-02-23             74     56      59      False
# 2020-03-01             74     54      62      False
# 2020-03-08             67     48      57      False
# 2020-03-15             40     35      34      False
# 2020-03-22             46     41      37      False
# 2020-03-29             49     41      46      False
# 2020-04-05             55     45      44      False
# 2020-04-12             60     47      47      False
# 2020-04-19             66     48      45      False
# 2020-04-26             70     49      48      False
# ...

# %%
plt.figure()
plt.plot(df.index,df.data_kering,'k*')
plt.plot(df.index,df.data_hermes,'r*')
plt.plot(df.index,df.data_kering,'b*')
plt.legend(['Louis Vuitton','Gucci','Hermes'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-43268b110e1e> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(df.index,df.data_kering,'k*')
#       3 plt.plot(df.index,df.data_hermes,'r*')
#       4 plt.plot(df.index,df.data_kering,'b*')
#       5 plt.legend(['Louis Vuitton','Gucci','Hermes'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data_kering'
